# %% [markdown]
# # Preprocessing
#
# Dataset: Quotes-500K (https://github.com/ShivaliGoel/Quotes-500K)
#
# Download links:
# - https://www.mediafire.com/file/elzplaxcnpf91qs/quotes.csv/file
# - https://drive.google.com/file/d/1M5TTqsLw7uVZfJfvH-fNpRxL9Mw0Iky8/view?usp=sharing
# - https://archive.org/details/quotes_20230625

# %%
import pandas as pd
import re

# %%
quotes_df = pd.read_csv('quotes.csv')
quotes_df
# Out:
#                                                     quote  \
# 0       I'm selfish, impatient and a little insecure. ...
# 1       You've gotta dance like there's nobody watchin...
# 2       You know you're in love when you can't fall as...
# 3       A friend is someone who knows all about you an...
# 4       Darkness cannot drive out darkness: only light...
# ...                                                   ...
# 499704  I do believe the most important thing I can do...
# 499705  I'd say I'm a bit antimadridista although I do...
# 499706                                 The future is now.
# 499707  In all my life and in the future, I will alway...
# 499708    The future is as bright as the promises of God.
#
#                                                    author  \
# 0                                          Marilyn Monroe
# 1                                       William W. Purkey
# 2                                               Dr. Seuss
# 3                                          Elbert Hubbard
# 4       Martin Luther King Jr., A Testament of Hope: T...
# ...                                                   ...
# 499704                                    John C. Stennis
# 499705                                               Isco
# 499706                                      Nam June Paik
# 499707                                   Norodom Sihamoni
# 499708                                      William Carey
#
#                                                  category
# 0       attributed-no-source, best, life, love, mistak...
# 1       dance, heaven, hurt, inspirational, life, love...
# 2       attributed-no-source, dreams, love, reality, s...
# 3                     friend, friendship, knowledge, love
# 4       darkness, drive-out, hate, inspirational, ligh...
# ...                                                   ...
# 499704                               Past, Believe, Help
# 499705                              Team, Humility, Know
# 499706                                               Now
# 499707                            Life, My Life, Servant
# 499708                             God, Promises, Bright
#
# [499709 rows x 3 columns]

# %%
# Remove category column - unnecessary for this project
quotes_df = quotes_df.drop(columns=['category'])

# Remove rows where quote is empty
quotes_df = quotes_df.dropna(subset=['quote'])

# Some rows have nulls in the author or category - we keep these
quotes_df = quotes_df.fillna('Unknown')

# %%
# Some entries in 'author' have NAME, BOOK TITLE (separated by comma): just get the NAME and discard BOOK TITLE
quotes_df['author'] = quotes_df['author'].apply(lambda x: x.split(',')[0] if isinstance(x, str) else x)
# Replace multiple spaces with single space
quotes_df['author'] = quotes_df['author'].apply(lambda x: re.sub(r' +', r' ', x) if isinstance(x, str) else x)
quotes_df['author'] = quotes_df['author'].str.strip()

def get_mismatched_rows(df):
    """
    Returns the rows in the dataframe where the data is entered incorrectly
    among the 'quote,' 'author,' and 'category' columns. Often, this occurs as
    part of the quote being entered in 'author', and the author being in
    'category.'

    We filter where the 'author' value is more than 5 words long as well as
    not being capitalised. This means the rows returned are unlikely to have
    the actual author in 'author', so we can safely presume the 'author' value
    is the continuation of the quote in 'quote.' This justifies concatenating
    the 'quote' and 'author' values after calling this function.
    """
    df['author_len'] = df['author'].apply(lambda x: len(x.split(' ')))
    df['author_caps'] = df['author'].apply(lambda x: x[0].isupper() if x != '' else False)

    rows_to_fix = df[(df['author_len'] > 5) & (df['author_caps'] == False)]
    return rows_to_fix

# %%
rows_to_fix = get_mismatched_rows(quotes_df)

# Concatenate the 'quote' and 'author' values
for index, row in rows_to_fix.iterrows():
    # Concatenate the 'author' value to the 'quote' and update 'author' with 'category'
    rows_to_fix.at[index, 'quote'] = row['quote'] + " " + row['author']
    # rows_to_fix.at[index, 'author'] = row['category']
    # rows_to_fix.at[index, 'category'] = ' '

rows_fixed = rows_to_fix
rows_fixed.head()
# Out:
#                                                   quote  \
# 807   If you love something so much let it go. If it...
# 1236  Submission is not about authority and it is no...
# 1917  Emotion without reason lets people walk all ov...
# 2730  We all are so deeply interconnected we have no...
# 2882  I'd run my whole life long to reach you paddle...
#
#                                                  author  author_len  \
# 807                          if it doesn't it never was           6
# 1236  it is all about relationships of love and resp...           9
# 1917      reason without emotion is a mask for cruelty.           8
# 2730  we have no option but to love all. Be kind and...          34
# 2882          paddle my way across Atlantic and Pacific           7
#
#       author_caps
# 807         False
# 1236        False
# 1917        False
# 2730        False
# 2882        False

# %%
# Replace the incorrect rows with the newly fixed rows
cleaned_df = pd.concat([quotes_df.drop(rows_fixed.index), rows_fixed])

get_mismatched_rows(cleaned_df)
# Now, we're just left with the rows where the author is unknown because the
# quote was split over all three columns. We, again, combine the values in
# 'quote' and 'author.'
# Out:
#                                                     quote  \
# 807     If you love something so much let it go. If it...
# 1236    Submission is not about authority and it is no...
# 1917    Emotion without reason lets people walk all ov...
# 2730    We all are so deeply interconnected we have no...
# 2882    I'd run my whole life long to reach you paddle...
# ...                                                   ...
# 424406  Being is always becoming people change and sta...
# 424693  We normally know we're getting older when the ...
# 424814  Cole was meticulous to a fault office scuttleb...
# 424825  Naivete in grownups is often charming but when...
# 425187  Gossip's like jam it don't bear fruit if you d...
#
#                                                    author  author_len  \
# 807                            if it doesn't it never was           6
# 1236    it is all about relationships of love and resp...           9
# 1917        reason without emotion is a mask for cruelty.           8
# 2730    we have no option but to love all. Be kind and...          34
# 2882            paddle my way across Atlantic and Pacific           7
# ...                                                   ...         ...
# 424406                   people change and stay the same.           6
# 424693  unless you're a cancer survivor! Then we love ...          11
# 424814  office scuttlebut had it that he never went ou...          17
# 424825  but when coupled with vanity it is indistingui...          10
# 425187        it don't bear fruit if you don't spread it.           9
#
#         author_caps
# 807           False
# 1236          False
# 1917          False
# 2730          False
# 2882          False
# ...             ...
# 424406        False
# 424693        False
# 424814        False
# 424825        False
# 425187        False
#
# [4895 rows x 4 columns]

# %%
rows_to_fix = get_mismatched_rows(cleaned_df)

# Concatenate the 'quote' and 'author' values
for index, row in rows_to_fix.iterrows():
    # Concatenate the 'author' value to the 'quote' and update 'author' with 'category'
    rows_to_fix.at[index, 'quote'] = row['quote'] + " " + row['author']
    # rows_to_fix.at[index, 'author'] = row['category']
    # rows_to_fix.at[index, 'category'] = ' '

rows_fixed = rows_to_fix
rows_fixed.head()
# Out:
#                                                   quote  \
# 807   If you love something so much let it go. If it...
# 1236  Submission is not about authority and it is no...
# 1917  Emotion without reason lets people walk all ov...
# 2730  We all are so deeply interconnected we have no...
# 2882  I'd run my whole life long to reach you paddle...
#
#                                                  author  author_len  \
# 807                          if it doesn't it never was           6
# 1236  it is all about relationships of love and resp...           9
# 1917      reason without emotion is a mask for cruelty.           8
# 2730  we have no option but to love all. Be kind and...          34
# 2882          paddle my way across Atlantic and Pacific           7
#
#       author_caps
# 807         False
# 1236        False
# 1917        False
# 2730        False
# 2882        False

# %%
# Replace the incorrect rows with the newly fixed rows
cleaned_df = pd.concat([cleaned_df.drop(rows_fixed.index), rows_fixed])

# %%
get_mismatched_rows(cleaned_df)
# Left with nothing mismatched according to our heuristic in the mismatched function!
# Out:
#                                                     quote  \
# 807     If you love something so much let it go. If it...
# 1236    Submission is not about authority and it is no...
# 1917    Emotion without reason lets people walk all ov...
# 2730    We all are so deeply interconnected we have no...
# 2882    I'd run my whole life long to reach you paddle...
# ...                                                   ...
# 424406  Being is always becoming people change and sta...
# 424693  We normally know we're getting older when the ...
# 424814  Cole was meticulous to a fault office scuttleb...
# 424825  Naivete in grownups is often charming but when...
# 425187  Gossip's like jam it don't bear fruit if you d...
#
#                                                    author  author_len  \
# 807                            if it doesn't it never was           6
# 1236    it is all about relationships of love and resp...           9
# 1917        reason without emotion is a mask for cruelty.           8
# 2730    we have no option but to love all. Be kind and...          34
# 2882            paddle my way across Atlantic and Pacific           7
# ...                                                   ...         ...
# 424406                   people change and stay the same.           6
# 424693  unless you're a cancer survivor! Then we love ...          11
# 424814  office scuttlebut had it that he never went ou...          17
# 424825  but when coupled with vanity it is indistingui...          10
# 425187        it don't bear fruit if you don't spread it.           9
#
#         author_caps
# 807           False
# 1236          False
# 1917          False
# 2730          False
# 2882          False
# ...             ...
# 424406        False
# 424693        False
# 424814        False
# 424825        False
# 425187        False
#
# [4895 rows x 4 columns]

# %%
# Replace all empty strings with whitespace before converting to CSV.
# Otherwise, when we read the CSV back in, the value will be registered as NULL.
cleaned_df = cleaned_df.replace('', ' ')

# Remove indicator columns we no longer need
output_df = cleaned_df.drop(['author_len', 'author_caps'], axis=1)

# Export
# output_df.to_csv('quotes_clean.csv', index=False)

# %% [markdown]
# ### An aside...

# %%
# There are still 2000+ rows where the quote is split... but these are more
# annoying to handle because the 'author' starts with a capital letter, but is
# longer than 5 words. This could be an author, or an author + book title.
# 2500 is only 0.5% of our 500,000 quote dataset, so not worth the effort!
cleaned_df[cleaned_df['author_len'] > 5]
# Out:
#                                                     quote  \
# 2757                                       Don't touch me
# 2885               Just in case you ever foolishly forget
# 2918                              I'm not afraid of death
# 3418    I don't want to achieve immortality through my...
# 3965                                    Life is but a day
# ...                                                   ...
# 424406  Being is always becoming people change and sta...
# 424693  We normally know we're getting older when the ...
# 424814  Cole was meticulous to a fault office scuttleb...
# 424825  Naivete in grownups is often charming but when...
# 425187  Gossip's like jam it don't bear fruit if you d...
#
#                                                    author  author_len  \
# 2757                            I'll die if you touch me.           6
# 2885                       I'm never not thinking of you.           6
# 2918       I just don't want to be there when it happens.          10
# 3418    I want to achieve immortality through not dyin...          20
# 3965    A fragile dew-drop on its perilous wayFrom a t...          10
# ...                                                   ...         ...
# 424406                   people change and stay the same.           6
# 424693  unless you're a cancer survivor! Then we love ...          11
# 424814  office scuttlebut had it that he never went ou...          17
# 424825  but when coupled with vanity it is indistingui...          10
# 425187        it don't bear fruit if you don't spread it.           9
#
#         author_caps
# 2757           True
# 2885           True
# 2918           True
# 3418           True
# 3965           True
# ...             ...
# 424406        False
# 424693        False
# 424814        False
# 424825        False
# 425187        False
#
# [5964 rows x 4 columns]

# %% [markdown]
# ### Make quotes_clean file smaller!

# %%
import re
output_df['quote_stripped'] = output_df['quote'].apply(lambda x: re.sub('[^a-z]', '', x.lower()))
output_df.drop_duplicates(subset='quote_stripped', keep='first', inplace=True)
output_df.drop(columns=['quote_stripped'], inplace=True)
output_df
# Out:
#                                                     quote  \
# 0       I'm selfish, impatient and a little insecure. ...
# 1       You've gotta dance like there's nobody watchin...
# 2       You know you're in love when you can't fall as...
# 3       A friend is someone who knows all about you an...
# 4       Darkness cannot drive out darkness: only light...
# ...                                                   ...
# 424406  Being is always becoming people change and sta...
# 424693  We normally know we're getting older when the ...
# 424814  Cole was meticulous to a fault office scuttleb...
# 424825  Naivete in grownups is often charming but when...
# 425187  Gossip's like jam it don't bear fruit if you d...
#
#                                                    author
# 0                                          Marilyn Monroe
# 1                                       William W. Purkey
# 2                                               Dr. Seuss
# 3                                          Elbert Hubbard
# 4                                  Martin Luther King Jr.
# ...                                                   ...
# 424406                   people change and stay the same.
# 424693  unless you're a cancer survivor! Then we love ...
# 424814  office scuttlebut had it that he never went ou...
# 424825  but when coupled with vanity it is indistingui...
# 425187        it don't bear fruit if you don't spread it.
#
# [488718 rows x 2 columns]

# %%
output_df = output_df[output_df['author'].apply(lambda x: len(x.split()) <= 5)]
output_df
# Out:
#                                                     quote  \
# 0       I'm selfish, impatient and a little insecure. ...
# 1       You've gotta dance like there's nobody watchin...
# 2       You know you're in love when you can't fall as...
# 3       A friend is someone who knows all about you an...
# 4       Darkness cannot drive out darkness: only light...
# ...                                                   ...
# 499704  I do believe the most important thing I can do...
# 499705  I'd say I'm a bit antimadridista although I do...
# 499706                                 The future is now.
# 499707  In all my life and in the future, I will alway...
# 499708    The future is as bright as the promises of God.
#
#                         author
# 0               Marilyn Monroe
# 1            William W. Purkey
# 2                    Dr. Seuss
# 3               Elbert Hubbard
# 4       Martin Luther King Jr.
# ...                        ...
# 499704         John C. Stennis
# 499705                    Isco
# 499706           Nam June Paik
# 499707        Norodom Sihamoni
# 499708           William Carey
#
# [482778 rows x 2 columns]

# %%
# Sample rows to get under 100mb for github
final_output_df = output_df.sample(n=450000, random_state=1)

final_output_df.to_csv('quotes_clean.csv', index=False)
